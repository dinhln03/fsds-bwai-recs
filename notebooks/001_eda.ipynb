# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys

sys.path.insert(0, "..")

# %%
import pandas as pd

from src.constants import PROJECT_ROOT_DIR, INT_FOLDER, CSV_DATASET_FILE

# %%
raw_df = pd.read_csv(PROJECT_ROOT_DIR / INT_FOLDER / CSV_DATASET_FILE)

# %%
with pd.option_context("display.max_columns", None):
    display(raw_df.head(3))
# Out:
#                                                  toc  \
# 0  {'categories': [{'id': 'vteif6s30', 'title': '...
# 1  {'categories': [{'id': 'xrb1qmtu7', 'title': '...
# 2  {'categories': [{'id': 'z5h51s0q1', 'title': '...
#
#                                     title  \
# 0  Bulletproof Ruby on Rails Applications
# 1               Business Machine Learning
# 2   C++ Brain Teasers: Exercise Your Mind
#
#                                              summary  \
# 0  This course aims to teach you how to write bet...
# 1  AI has enabled us to develop machine learning ...
# 2  C++, a powerful and versatile programming lang...
#
#                                        brief_summary details  \
# 0  Gain insights into good testing practices in R...     NaN
# 1  Delve into business machine learning, gaining ...     NaN
# 2  Gain insights into C++ through engaging puzzle...     NaN
#
#                                                 clos  \
# ...

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1119 entries, 0 to 1118
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   toc                      1119 non-null   object
#  1   title                    1119 non-null   object
#  2   summary                  1119 non-null   object
#  3   brief_summary            1100 non-null   object
#  4   details                  127 non-null    object
#  5   clos                     1119 non-null   object
#  6   tags                     1119 non-null   object
#  7   target_audience          1118 non-null   object
#  8   cover_image_serving_url  1117 non-null   object
#  9   url_slug                 1119 non-null   object
#  10  read_time                1119 non-null   int64
#  11  learner_tags             1119 non-null   object
#  12  level_one_learner_tags   1119 non-null   object
# dtypes: int64(1), object(12)
# memory usage: 113.8+ KB
